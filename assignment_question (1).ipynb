# %% [markdown]
# 1.Syntax and Semantics
#
# Question 1: Write a Python program to print "Hello, World!".

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Question 2: Write a Python program that takes a user input and prints it.

# %%
user_input = input("Please enter your name: ")
print(f"Hello, {user_input}!")
# Out:
# Hello, priya!

# %% [markdown]
# Question 3: Write a Python program to check if a number is positive, negative, or zero.

# %%
number = float(input("Enter the number: "))
if number > 0:
    print("The number is positive.")
elif number < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# The number is positive.

# %% [markdown]
# Question 4: Write a Python program to find the largest of three numbers.

# %%
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))
number3 = int(input("Enter the third number: "))
if number1 >= number2 and number1 >= number3:
    largest = number1
elif number2 >= number1 and number2 >= number3:
    largest = number2
else:
    largest = number3
print("The largest number is:", largest)
# Out:
# The largest number is: 14

# %% [markdown]
# Question 5: Write a Python program to calculate the factorial of a number.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)
number = int(input("Enter a number to find its factorial: "))
print(f"The factorial of {number} is {factorial(number)}")
# Out:
# The factorial of 5 is 120

# %% [markdown]
# 2. Variables and Data Types
#
# Question 6: Create variables of different data types: integer, float, string, and boolean. Print their values and types.
#
#
# [ ]

# %%
age = 17
price = 99.99
name = "Anu"
is_student = True
print(f"Name: {name}, Age: {age}, Price: {price}, Is Student: {is_student}")
print("Data type are :", type(age), type(price), type(name), type(is_student))
# Out:
# Name: Anu, Age: 17, Price: 99.99, Is Student: True
# Data type are : <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %% [markdown]
# Question 7: Write a Python program to swap the values of two variables.
#
#
# [ ]

# %%
a = 7
b = 3
print(f"Before swapping a = {a}, b = {b}")
a, b = b,a
print(f"After swapping a = {a}, b = {b}")
# Out:
# Before swapping a = 7, b = 3
# After swapping a = 3, b = 7

# %% [markdown]
# Question 8: Write a Python program to convert Celsius to Fahrenheit.

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius} degrees Celsius is equal to {fahrenheit} degrees Fahrenheit.")
# Out:
# 37.0 degrees Celsius is equal to 98.6 degrees Fahrenheit.

# %% [markdown]
# uestion 9: Write a Python program to concatenate two strings.
#
#
# [ ]

# %%
str1 = "Hello"
str2 = "World"
concatenated = str1 + " " + str2
print(concatenated)
# Out:
# Hello World

# %% [markdown]
# Question 10: Write a Python program to check if a variable is of a specific data type.

# %%
my_var = 24
if isinstance(my_var, int):
    print("my_var is an integer.")
else:
    print("my_var is not an integer.")
# Out:
# my_var is an integer.

# %% [markdown]
# 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# Question 11: Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.
#
#
# [ ]

# %%
a = 10
b = 5
print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
# Out:
# Addition: 10 + 5 = 15
# Subtraction: 10 - 5 = 5
# Multiplication: 10 * 5 = 50
# Division: 10 / 5 = 2.0

# %% [markdown]
# Question 12: Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.
#
#
# [ ]

# %%
a = 40
b = 20
print(f"equal to: {a} == {b} is {a == b}")
print(f"not equal to: {a} != {b} is {a != b}")
print(f"greater than: {a} > {b} is {a > b}")
print(f"less than: {a} < {b} is {a < b}")
# Out:
# equal to: 40 == 20 is False
# not equal to: 40 != 20 is True
# greater than: 40 > 20 is True
# less than: 40 < 20 is False

# %% [markdown]
# Question 13: Write a Python program to demonstrate logical operators: and, or, not.

# %%
x1 = 5
y1 = 10
print(f"Logical AND: {x1} > 0 and {y1} > 0 is {(x1 > 0) and (y1 > 0)}")
print(f"Logical OR: {x1} > 0 or {y1} < 0 is {(x1 > 0) or (y1 < 0)}")
print(f"Logical NOT: not ({x1} > 0) is {not (x1 > 0)}")
# Out:
# Logical AND: 5 > 0 and 10 > 0 is True
# Logical OR: 5 > 0 or 10 < 0 is True
# Logical NOT: not (5 > 0) is False

# %% [markdown]
# Question 14: Write a Python program to calculate the square of a number.

# %%
x = 8
print (square := x ** 2)
# Out:
# 64

# %% [markdown]
# uestion 15: Write a Python program to check if a number is even or odd.

# %%
a = 17
if a % 2 == 0:
    print(f"{a} is an even number.")
else:
    print(f"{a} is an odd number.")
# Out:
# 17 is an odd number.

# %% [markdown]
# Question 16: Write a Python program to find the sum of the first n natural numbers.

# %%
n = int(input("Enter a number: "))
sum_n = (n* (n+1)) // 2
print(f"The sum of the first {n} natural numbers is: {sum_n}")
# Out:
# The sum of the first 5 natural numbers is: 15

# %% [markdown]
# Question 17: Write a Python program to check if a year is a leap year.
#
#
# [ ]

# %%
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
# Out:
# 2024 is a leap year.

# %% [markdown]
# Question 18: Write a Python program to reverse a string.
#
#
# [ ]

# %%
string = input("Enter a string: ")
reversed_string = string[::-1]
print(f"The reversed string is: {reversed_string}")
# Out:
# The reversed string is: ayhtiN olleH

# %% [markdown]
# Question 19: Write a Python program to check if a string is a palindrome.
#
#
# [ ]

# %%
string = input("Enter a string: ")
if string == string[::-1]:
    print(f"{string} is a palindrome.")
else:
    print(f"{string} is not a palindrome.")
# Out:
# level is a palindrome.

# %% [markdown]
# Question 20: Write a Python program to sort a list of numbers in ascending order.

# %%
number =[5,2,9,1,3,4]
number.sort()
print(f"The sorted list is: {number}")
# Out:
# The sorted list is: [1, 2, 3, 4, 5, 9]
